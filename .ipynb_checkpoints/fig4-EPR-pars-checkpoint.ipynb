# %%
# import all the relevant packages.
using Plots, LaTeXStrings, Distributions, DoubleFloats, Plots.PlotMeasures, LinearAlgebra, DataFrames, CSV
Plots.theme(:dao)

# %%
pal = cgrad(:tol_muted);
cpal = [pal[i] for i in 0.1:0.1:1.0]
# Out:
# 10-element Array{RGBA{Float64},1} with eltype RGBA{Float64}:
#  RGBA{Float64}(0.4666666666666667,0.6666666666666667,0.8533333333333334,1.0)
#  RGBA{Float64}(0.3733333333333333,0.72,0.7333333333333333,1.0)
#  RGBA{Float64}(0.1866666666666667,0.5866666666666667,0.44000000000000006,1.0)
#  RGBA{Float64}(0.17333333333333342,0.49333333333333335,0.2,1.0)
#  RGBA{Float64}(0.6,0.6,0.2,1.0)
#  RGBA{Float64}(0.8133333333333334,0.76,0.4133333333333333,1.0)
#  RGBA{Float64}(0.8266666666666668,0.5600000000000002,0.4666666666666667,1.0)
#  RGBA{Float64}(0.6933333333333332,0.2933333333333333,0.41333333333333333,1.0)
#  RGBA{Float64}(0.5599999999999998,0.1599999999999999,0.38666666666666644,1.0)
#  RGBA{Float64}(0.6666666666666666,0.26666666666666666,0.6,1.0)

# %%
B_data = CSV.read("./B-tab.csv", DataFrame, header = false)
σoff_data = CSV.read("./sigma-off-tab.csv", DataFrame, header = false)
σon_data = CSV.read("./sigma-on-tab.csv", DataFrame, header = false)
ρoff_data = CSV.read("./rho-off-tab.csv", DataFrame, header = false);

# %%
p1 = plot(grid = false, minorgrid = false, legend = :topright, size = (300,300), xlabel = L"$B$", legendfontsize = 12,
xtickfontsize = 12, ytickfontsize = 12, xlabelfontsize = 18, ylabel = L"\dot{s}_{\mathrm{mac}}", ylabelfontsize = 18)
plot!(B_data[:,1], B_data[:,2], color = :black, label = :none)

# %%
p2 = plot(grid = false, minorgrid = false, legend = :bottomright, size = (300,300), xlabel = L"$\sigma_{\mathrm{off}}$", legendfontsize = 12,
xtickfontsize = 12, ytickfontsize = 12, xlabelfontsize = 18, ylims = [0,100])
plot!(σoff_data[:,1], σoff_data[:,2], color = :black, label = :none, xaxis = :log)
plot!([equiv_σoff,equiv_σoff],[0,100],linestyle = :dash, color = :black, label = "expt.")

# %% [markdown]
# Calculate the mean $\sigma_{on}$ from the $\sigma_u$ column in Table 1 of Ramon's paper.

# %%
σon_expt = (0.0061+0.0029+0.0028+0.0251+0.0346+0.0265+0.0344+0.0077+0.0085+0.0109+0.0073+0.0124+0.0087+0.0119+0.0094+0.0089)/16
# Out:
# 0.01363125

# %% [markdown]
# Ratio of timescales is...

# %%
δ_expt = (10.93+89.83+53.11+10.21+8.55+4.86+6.71+16.66+20.51+13.57+13.49+10.15+18.86+12.08+14.54+17.66)/16
# Out:
# 20.107500000000005

# %%
equiv_σon = δ_expt*3 # σoff = 3.
# Out:
# 60.32250000000002

# %%
equiv_σoff = 3/δ_expt # σoff = 3.
# Out:
# 0.14919806042521444

# %%
p3 = plot(grid = false, minorgrid = false, legend = :topleft, size = (300,300), xlabel = L"$\sigma_{\mathrm{on}}$", legendfontsize = 10,
xtickfontsize = 12, ytickfontsize = 12, xlabelfontsize = 18, ylabel = L"\dot{s}_{\mathrm{mac}}", 
ylabelfontsize = 18, ylims = [0,10])
plot!(σon_data[:,1], σon_data[:,2], color = :black, label = :none, xaxis = :log)
plot!([equiv_σon,equiv_σon],[0,10],linestyle = :dash, color = :black, label = "expt.")
plot!([12^0.5,12^0.5],[0,10],linestyle = :dashdot, label = "max", color = cpal[2], lw = 2)

# %%
p4 = plot(grid = false, minorgrid = false, legend = :topright, size = (300,300), xlabel = L"$\rho_{\mathrm{off}}$", legendfontsize = 12,
xtickfontsize = 12, ytickfontsize = 12, xlabelfontsize = 18)
plot!(ρoff_data[:,1], ρoff_data[:,2], color = :black, label = :none, xaxis = :log)

# %%
combplot = plot(p1,p2,p3,p4,layout = (2,2), size = (600,600))
